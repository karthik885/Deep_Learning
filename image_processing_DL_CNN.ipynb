# %%
# !wget 'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRNvridF1oyNevmvnR9kWn1Rw7wmgJgYY3E4-PV_24Mq6LobU59uHr-XcU&s'
# Out:
# --2024-12-26 05:47:57--  https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRNvridF1oyNevmvnR9kWn1Rw7wmgJgYY3E4-PV_24Mq6LobU59uHr-XcU&s
# Resolving encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)... 172.217.15.238, 2607:f8b0:4025:802::200e
# Connecting to encrypted-tbn0.gstatic.com (encrypted-tbn0.gstatic.com)|172.217.15.238|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9371 (9.2K) [image/jpeg]
# Saving to: ‘images?q=tbn:ANd9GcRNvridF1oyNevmvnR9kWn1Rw7wmgJgYY3E4-PV_24Mq6LobU59uHr-XcU&s’
#
# images?q=tbn:ANd9Gc 100%[===================>]   9.15K  --.-KB/s    in 0s
#
# 2024-12-26 05:47:57 (37.7 MB/s) - ‘images?q=tbn:ANd9GcRNvridF1oyNevmvnR9kWn1Rw7wmgJgYY3E4-PV_24Mq6LobU59uHr-XcU&s’ saved [9371/9371]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread('/content/image')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (148, 270, 3)

# %%
print(img)
# Out:
# [[[27 26 32]
#   [27 26 32]
#   [27 26 32]
#   ...
#   [15 13 27]
#   [15 13 27]
#   [15 13 27]]
#
#  [[27 26 32]
#   [27 26 32]
#   [27 26 32]
#   ...
#   [21 17 31]
#   [20 16 31]
#   [19 15 29]]
#
#  [[27 26 32]
#   [27 26 32]
#   [27 26 32]
#   ...
#   [22 16 28]
#   [21 15 29]
#   [20 14 26]]
#
#  ...
#
#  [[24 25 30]
#   [24 25 30]
#   [23 24 29]
#   ...
#   [20 12 25]
#   [20 12 25]
#   [20 12 25]]
#
#  [[24 25 30]
#   [24 25 30]
#   [23 24 29]
#   ...
#   [23 15 28]
#   [23 15 28]
#   [23 15 28]]
#
#  [[24 25 30]
#   [24 25 30]
#   [23 24 29]
#   ...
#   [24 16 29]
#   [24 16 29]
#   [24 16 29]]]

# %%
img_plot=plt.imshow(img)

# %%
from PIL import Image

# %%
img=Image.open('/content/image')
img_resized=img.resize((200,200))

# %%
img_resized.save('image_resized_1.jpg')

# %%
img_res=mpimg.imread('/content/image_resized_1.jpg')
img_res_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img=cv2.imread('/content/image')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (148, 270)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=270x148>

# %%
grayscale_image
# Out:
# array([[27, 27, 27, ..., 15, 15, 15],
#        [27, 27, 27, ..., 20, 19, 18],
#        [27, 27, 27, ..., 19, 18, 17],
#        ...,
#        [25, 25, 24, ..., 16, 16, 16],
#        [25, 25, 24, ..., 19, 19, 19],
#        [25, 25, 24, ..., 20, 20, 20]], dtype=uint8)

# %%
cv2.imwrite('image_grayscale_image.jpg',grayscale_image)
# Out:
# True
